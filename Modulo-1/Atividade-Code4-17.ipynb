# %% [markdown]
# <a href="https://colab.research.google.com/github/pedro-varela1/CursoFAP-SoftexPernambuco/blob/main/Atividade-Code4-17.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Atividade com Código 4 - FAP
#
# ## Instrução
# Desenvolva um programa que deve ler um arquivo csv intitulado “notas_alunos.csv”. O arquivo deve ter a seguinte estrutura:
#
# - aluno: Nome do aluno;
# - nota_1: Primeira nota;
# - nota_2: Segunda nota;
# - faltas: Número de faltas;
#
# O programa lerá esse arquivo e criará duas colunas. A primeira coluna será “media”, que terá a média das duas notas do aluno. A segunda será “situacao”, com os valores: APROVADO ou REPROVADO.
#
# O aluno que tiver mais de 5 faltas ou possuir média menor que sete, será reprovado. O programa deverá salvar esse novo dataframe com o nome “alunos_situacao.csv”.
#
# Por fim, o programa deverá mostrar na tela:
# - o maior número de faltas;
# - a média geral das notas dos alunos;
# - e a maior média.
#
# Veja em anexo um exemplo do arquivo “notas_alunos.csv”.
#
# ---

# %% [markdown]
# ## Resolução
#
# A resolução foi feita em Pyhton e está exposta abaixo, passo a passo.

# %% [markdown]
# Primeiramente, vamos criar um dictionary contendo os dados do arquivo .csv que será realizado a leitura:

# %%
notas_alunos = {
    'aluno': ['aluno_1', 'aluno_2', 'aluno_3', 'aluno_4'],
    'nota_1': [7, 3, 9, 10],
    'nota_2': [7, 10, 4, 6],
    'faltas': [1, 7, 2, 9]
}

# %% [markdown]
# Agora, vamos converter esse dict em um arquivo .csv:

# %%
import csv      #Biblioteca utilizada

# Nome do arquivo CSV que queremos criar
nome_arquivo = 'notas_alunos.csv'

# Abrindo o arquivo CSV em modo de escrita
with open(nome_arquivo, 'w', newline='') as arquivo_csv:
    # Criando o objeto writer para escrever no arquivo CSV
    writer = csv.writer(arquivo_csv)

    # Escrevendo o cabeçalho (nome das colunas) no arquivo CSV
    writer.writerow(['aluno', 'nota_1', 'nota_2', 'faltas'])

    # Escrevendo os dados dos alunos no arquivo CSV
    for i in range(len(notas_alunos['aluno'])):
        aluno = notas_alunos['aluno'][i]
        nota_1 = notas_alunos['nota_1'][i]
        nota_2 = notas_alunos['nota_2'][i]
        faltas = notas_alunos['faltas'][i]
        writer.writerow([aluno, nota_1, nota_2, faltas])

print(f"O arquivo '{nome_arquivo}' foi criado com sucesso!")
# Out:
# O arquivo 'notas_alunos.csv' foi criado com sucesso!

# %% [markdown]
# Arquivo criado, show de bola! Vamos transformar o arquivo em um _pandas dataframe_ para podermos dar uma olhada e manipulá-lo:

# %%
import pandas as pd     # Vamos utilizar o pandas!

df_notas = pd.read_csv("/content/notas_alunos.csv")

df_notas # Uma checada é sempre bom
# Out:
#      aluno  nota_1  nota_2  faltas
# 0  aluno_1       7       7       1
# 1  aluno_2       3      10       7
# 2  aluno_3       9       4       2
# 3  aluno_4      10       6       9

# %% [markdown]
# Observe os números na esquerda, se trata do id daquele aluno no dataframe. Vamos mudar o id para a coluna _aluno_, ou seja, o id será o nome do aluno:

# %%
df_notas = df_notas.set_index('aluno')
df_notas
# Out:
#          nota_1  nota_2  faltas
# aluno
# aluno_1       7       7       1
# aluno_2       3      10       7
# aluno_3       9       4       2
# aluno_4      10       6       9

# %% [markdown]
# Como solicitado, será criada a coluna da média em um novo dataframe:

# %%
df_situacao = df_notas.copy()   # Dataframe novo copiado do antigo

df_situacao['media'] = (df_situacao['nota_1'] + df_situacao['nota_2'])/2    # Criacao da coluna da media

df_situacao
# Out:
#          nota_1  nota_2  faltas  media
# aluno
# aluno_1       7       7       1    7.0
# aluno_2       3      10       7    6.5
# aluno_3       9       4       2    6.5
# aluno_4      10       6       9    8.0

# %% [markdown]
# E a coluna da situção:

# %%
df_situacao['situacao'] = df_situacao.apply(
    lambda x: 'APROVADO' if ((x['media']>=7) and (x['faltas']<=5)) else 'REPROVADO',
    axis=1
    )   # Condições estabelecidas para aprovação e reprovação

df_situacao
# Out:
#          nota_1  nota_2  faltas  media   situacao
# aluno
# aluno_1       7       7       1    7.0   APROVADO
# aluno_2       3      10       7    6.5  REPROVADO
# aluno_3       9       4       2    6.5  REPROVADO
# aluno_4      10       6       9    8.0  REPROVADO

# %% [markdown]
# Vamos transformar esse dataframe novamente em um arquivo .csv:

# %%
df_situacao.to_csv(path_or_buf='alunos_situacao.csv')

# %% [markdown]
# Vamos ver o maior número de faltas e o aluno que teve essas faltas:

# %%
# Maior número de faltas
df_situacao['faltas'].max()
# Out:
# 9

# %%
# Aluno com essas faltas
df_situacao.loc[lambda x: x['faltas'] == df_situacao['faltas'].max()]
# Out:
#          nota_1  nota_2  faltas  media   situacao
# aluno
# aluno_4      10       6       9    8.0  REPROVADO

# %% [markdown]
# Foi o aluno_4, com 9 faltas!

# %% [markdown]
# A média geral das notas dos alunos é:

# %%
df_situacao['media'].mean()
# Out:
# 7.0

# %% [markdown]
# A maior média e o aluno com a maior média são respectivamente:

# %%
# Maior media
df_situacao['media'].max()
# Out:
# 8.0

# %%
# Aluno essa media
df_situacao.loc[lambda x: x['media'] == df_situacao['media'].max()]
# Out:
#          nota_1  nota_2  faltas  media   situacao
# aluno
# aluno_4      10       6       9    8.0  REPROVADO

# %% [markdown]
# O aluno_4! E ainda foi reprovado por falta.

# %% [markdown]
# ---
#
# Podemos escrever o código completo em Python:
#
# ```python
# import pandas as pd
#
# df_notas = pd.read_csv("/content/notas_alunos.csv")
# df_notas = df_notas.set_index('aluno')
#
# df_situacao = df_notas.copy()
#
# df_situacao['media'] = (df_situacao['nota_1'] + df_situacao['nota_2'])/2
#
# df_situacao['situacao'] = df_situacao.apply(
#     lambda x: 'APROVADO' if ((x['media']>=7) and (x['faltas']<=5)) else 'REPROVADO',
#     axis=1
#     )
#
# df_situacao.to_csv(path_or_buf='alunos_situacao.csv')
#
# print(f"O maior número de faltas foi {df_situacao['faltas'].max()}")
# print(f"A media geral dos alunos foi {df_situacao['media'].mean()}")
# print(f"A maior média foi {df_situacao['media'].max()}")
# ```
